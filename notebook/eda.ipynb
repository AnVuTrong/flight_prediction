# %%
import pandas as pd

# %%
raw = pd.read_csv('../data/csv/raw.csv')

raw
# Out:
#        wind_speed_TSN  wind_dir_TSN  wind_speed_KADUM  wind_dir_KADUM  \
# 0                 3.2         130.9               1.1           130.3
# 1                 3.2         130.9               1.1           130.4
# 2                 3.2         130.9               1.1           130.4
# 3                 3.2         130.9               1.1           130.5
# 4                 3.2         130.9               1.1           130.5
# ...               ...           ...               ...             ...
# 61383             1.9         137.2               1.8            42.6
# 61384             1.9         137.2               1.8            42.6
# 61385             1.9         137.2               1.8            42.2
# 61386             1.9         137.2               1.8            42.2
# 61387             1.9         137.3               1.8            41.9
#
#        wind_speed_PATNA  wind_dir_PATNA  wind_speed_SADAS  wind_dir_SADAS  \
# 0                   2.4           202.5               0.8           142.5
# 1                   2.4           202.9               0.8           142.6
# 2                   2.4           202.9               0.8           142.6
# 3                   2.4           203.3               0.7           142.8
# 4                   2.4           203.3               0.7           142.8
# ...                 ...             ...               ...             ...
# 61383               5.3            37.8               3.4            95.0
# 61384               5.3            37.8               3.4            95.0
# 61385               5.3            37.8               3.4            95.0
# 61386               5.3            37.8               3.4            95.0
# 61387               5.3            37.7               3.4            95.0
#
#        wind_speed_DADEN  wind_dir_DADEN  ...  Route        Ac_id  Ac_code  \
# 0                   1.6           141.7  ...      6  R6-VJ150-21    VJ150
# 1                   1.6           141.5  ...      6  R6-VJ150-21    VJ150
# 2                   1.6           141.5  ...      6  R6-VJ150-21    VJ150
# 3                   1.6           141.4  ...      6  R6-VJ150-21    VJ150
# 4                   1.6           141.4  ...      6  R6-VJ150-21    VJ150
# ...                 ...             ...  ...    ...          ...      ...
# 61383               3.9            97.4  ...      6  R6-VN258-04    VN258
# 61384               3.9            97.4  ...      6  R6-VN258-04    VN258
# 61385               3.9            97.4  ...      6  R6-VN258-04    VN258
# 61386               3.9            97.4  ...      6  R6-VN258-04    VN258
# 61387               3.9            97.4  ...      6  R6-VN258-04    VN258
#
#        Ac_type  Ac_kts  Time_step  Phase   Ac_Lat    Ac_Lon  Ac_feet
# 0            1   170.0          3      1  10.8134  106.6427    625.0
# 1            1   179.0         23      1  10.8075  106.6271   1425.0
# 2            1   205.0         43      1  10.8029  106.6096   1800.0
# 3            1   231.0         59      1  10.8063  106.5941   2025.0
# 4            1   255.0         75      1  10.8204  106.5810   2475.0
# ...        ...     ...        ...    ...      ...       ...      ...
# 61383        2   157.0       5344      1  21.2532  105.6876   1775.0
# 61384        2   152.0       5362      1  21.2493  105.7010   1525.0
# 61385        2   146.0       5378      1  21.2461  105.7121   1325.0
# 61386        2   131.0       5412      1  21.2401  105.7331    950.0
# 61387        2   138.0       5480      1  21.2276  105.7764    150.0
#
# [61388 rows x 46 columns]

# %%
lst_flight = raw['Ac_code'].unique().tolist()
lst_flight
# Out:
# ['VJ150',
#  'BL6018',
#  'VJ132',
#  'QH9216',
#  'QH262',
#  'BL6046',
#  'VN248',
#  'VJ198',
#  'QH246',
#  'VJ162',
#  'VN7222',
#  'BL6048',
#  'VJ126',
#  'QH224',
#  'QH204',
#  'VJ122',
#  'VU750',
#  'VN244',
#  'VJ6018',
#  'VN208',
#  'BL6002',
#  'VJ156',
#  'VN216',
#  'VN246',
#  'VJ6126',
#  'VN258',
#  'VN7320',
#  'BL6012',
#  'VN7214',
#  'QH240',
#  'VJ6132',
#  'VN7228',
#  'VN7240',
#  'QH9201',
#  'VN7218',
#  'VN7232',
#  'VN7216',
#  'VJ503',
#  'VN171',
#  'VN163',
#  'VJ6122',
#  'VN7224',
#  'VNA299',
#  'VL6012',
#  'VN240',
#  'VN299',
#  'QH244',
#  'VN7244',
#  'VJ750',
#  'VN204',
#  'VN224',
#  'QH9455',
#  'QH9457',
#  'VJ134',
#  'VN212',
#  'VN214',
#  'VN218',
#  'VU752',
#  'VN126']

# %%
raw[raw['Ac_code']=='BL6048'].shape[0]
# Out:
# 2439

# %%
print(f'The number of data point:')
for flg in lst_flight:
    print(f"Flight {flg}: {raw[raw['Ac_code']==flg].shape[0]}")
# Out:
# The number of data point:
# Flight VJ150: 2529
# Flight BL6018: 2555
# Flight VJ132: 2025
# Flight QH9216: 172
# Flight QH262: 2196
# Flight BL6046: 2073
# Flight VN248: 3135
# Flight VJ198: 2260
# Flight QH246: 1898
# Flight VJ162: 3743
# Flight VN7222: 1193
# Flight BL6048: 2439
# Flight VJ126: 3617
# Flight QH224: 1750
# Flight QH204: 2072
# Flight VJ122: 2734
# Flight VU750: 893
# Flight VN244: 2377
# Flight VJ6018: 171
# Flight VN208: 497
# Flight BL6002: 341
# Flight VJ156: 667
# Flight VN216: 2335
# Flight VN246: 2066
# Flight VJ6126: 1011
# Flight VN258: 3459
# Flight VN7320: 176
# Flight BL6012: 939
# Flight VN7214: 176
# Flight QH240: 1154
# Flight VJ6132: 348
# Flight VN7228: 179
# Flight VN7240: 179
# Flight QH9201: 176
# Flight VN7218: 175
# Flight VN7232: 177
# Flight VN7216: 174
# Flight VJ503: 101
# Flight VN171: 98
# Flight VN163: 93
# Flight VJ6122: 349
# Flight VN7224: 173
# Flight VNA299: 170
# Flight VL6012: 179
# Flight VN240: 1904
# Flight VN299: 169
# Flight QH244: 524
# Flight VN7244: 167
# Flight VJ750: 184
# Flight VN204: 171
# Flight VN224: 169
# Flight QH9455: 182
# Flight QH9457: 171
# Flight VJ134: 170
# Flight VN212: 650
# Flight VN214: 666
# Flight VN218: 499
# Flight VU752: 369
# Flight VN126: 169

# %%
raw[raw['Ac_code']=='VJ6018']
# Out:
#       wind_speed_TSN  wind_dir_TSN  wind_speed_KADUM  wind_dir_KADUM  \
# 3933             1.1         111.7               1.1           144.3
# 3934             1.1         112.2               1.1           144.4
# 3935             1.1         112.2               1.1           144.4
# 3936             1.1         112.6               1.1           144.6
# 3937             1.1         112.6               1.1           144.6
# ...              ...           ...               ...             ...
# 4099             1.4          81.2               0.8            54.2
# 4100             1.4          81.2               0.8            54.2
# 4101             1.4          82.2               0.9            53.1
# 4102             1.4          82.2               0.9            53.1
# 4103             1.4          83.1               0.9            52.1
#
#       wind_speed_PATNA  wind_dir_PATNA  wind_speed_SADAS  wind_dir_SADAS  \
# 3933               3.1            50.1               3.2            59.0
# 3934               3.1            50.2               3.1            59.6
# 3935               3.1            50.2               3.1            59.6
# 3936               3.1            50.3               3.1            60.3
# 3937               3.1            50.3               3.1            60.3
# ...                ...             ...               ...             ...
# 4099               3.8            37.6               2.3            67.0
# 4100               3.8            37.6               2.3            67.0
# 4101               3.8            37.5               2.4            67.1
# 4102               3.8            37.5               2.4            67.1
# 4103               3.8            37.4               2.4            67.1
#
#       wind_speed_DADEN  wind_dir_DADEN  ...  Route         Ac_id  Ac_code  \
# 3933               2.2            23.2  ...      6  R6-VJ6018-27   VJ6018
# 3934               2.2            22.7  ...      6  R6-VJ6018-27   VJ6018
# 3935               2.2            22.7  ...      6  R6-VJ6018-27   VJ6018
# 3936               2.2            22.1  ...      6  R6-VJ6018-27   VJ6018
# 3937               2.2            22.1  ...      6  R6-VJ6018-27   VJ6018
# ...                ...             ...  ...    ...           ...      ...
# 4099               1.6            27.3  ...      6  R6-VJ6018-27   VJ6018
# 4100               1.6            27.3  ...      6  R6-VJ6018-27   VJ6018
# 4101               1.6            28.0  ...      6  R6-VJ6018-27   VJ6018
# 4102               1.6            28.0  ...      6  R6-VJ6018-27   VJ6018
# 4103               1.6            28.8  ...      6  R6-VJ6018-27   VJ6018
#
#       Ac_type  Ac_kts  Time_step  Phase   Ac_Lat    Ac_Lon  Ac_feet
# 3933        1   160.0          4      1  10.8137  106.6432    725.0
# 3934        1   164.0         20      1  10.8092  106.6321   1275.0
# 3935        1   190.0         39      1  10.8035  106.6177   1575.0
# 3936        1   217.0         55      1  10.7978  106.6028   1875.0
# 3937        1   239.0         71      1  10.7920  106.5862   2300.0
# ...       ...     ...        ...    ...      ...       ...      ...
# 4099        1   203.0       5663      1  21.2556  105.6616   2100.0
# 4100        1   190.0       5682      1  21.2550  105.6796   1775.0
# 4101        1   164.0       5708      1  21.2493  105.7009   1375.0
# 4102        1   142.0       5725      1  21.2458  105.7133   1125.0
# 4103        1   136.0       5745      1  21.2422  105.7258    900.0
#
# [171 rows x 46 columns]
